# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\UDHAYA KUMAR . R\Desktop\Oasis\archive (3)\CarPrice_Assignment.csv")

# %%
df.sample(3)
# Out:
#     car_ID  symboling               CarName fueltype aspiration doornumber  \
# 82      83          3  mitsubishi outlander      gas      turbo        two
# 60      61          0    mazda glc custom l      gas        std       four
# 48      49          0             jaguar xf      gas        std       four
#
#       carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 82  hatchback        fwd          front       95.9  ...         156
# 60      sedan        fwd          front       98.8  ...         122
# 48      sedan        rwd          front      113.0  ...         258
#
#     fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm  \
# 82        spdi       3.58    3.86              7.0        145     5000
# 60        2bbl       3.39    3.39              8.6         84     4800
# 48        mpfi       3.63    4.17              8.1        176     4750
#
#    citympg  highwaympg    price
# 82      19          24  12629.0
# 60      26          32   8495.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
df.shape
# Out:
# (205, 26)

# %%
df.size
# Out:
# 5330

# %%
print(df.shape[0])
print(df.shape[1])
# Out:
# 205
# 26

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df.isna().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Data Cleaning

# %%
df['CarName'].nunique()
# Out:
# 147

# %%
df['CarName'] = df['CarName'].apply(lambda x: x.split(' ',1)[0])
df.rename(columns={'CarName':'CompanyName'},inplace=True)

# %%
df.head()
# Out:
#    car_ID  symboling  CompanyName fueltype aspiration doornumber      carbody  \
# 0       1          3  alfa-romero      gas        std        two  convertible
# 1       2          3  alfa-romero      gas        std        two  convertible
# 2       3          1  alfa-romero      gas        std        two    hatchback
# 3       4          2         audi      gas        std       four        sedan
# 4       5          2         audi      gas        std       four        sedan
#
#   drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 0        rwd          front       88.6  ...         130        mpfi
# 1        rwd          front       88.6  ...         130        mpfi
# 2        rwd          front       94.5  ...         152        mpfi
# 3        fwd          front       99.8  ...         109        mpfi
# 4        4wd          front       99.4  ...         136        mpfi
#
#    boreratio  stroke compressionratio horsepower  peakrpm citympg  highwaympg  \
# ...

# %%
df.drop('car_ID',axis=1,inplace=True)

# %%
df.sample(3)
# Out:
#     symboling CompanyName fueltype aspiration doornumber    carbody  \
# 55          3       mazda      gas        std        two  hatchback
# 95          1      nissan      gas        std        two  hatchback
# 68         -1       buick   diesel      turbo       four      wagon
#
#    drivewheel enginelocation  wheelbase  carlength  ...  enginesize  \
# 55        rwd          front       95.3      169.0  ...          70
# 95        fwd          front       94.5      165.6  ...          97
# 68        rwd          front      110.0      190.9  ...         183
#
#     fuelsystem  boreratio stroke compressionratio  horsepower peakrpm  \
# 55        4bbl       3.33  3.255              9.4         101    6000
# 95        2bbl       3.15  3.290              9.4          69    5200
# 68         idi       3.58  3.640             21.5         123    4350
#
#     citympg  highwaympg    price
# 55       17          23  10945.0
# 95       31          37   7799.0
# ...

# %%
df['CompanyName'].nunique()
# Out:
# 28

# %%
df['CompanyName'].value_counts()
# Out:
# toyota         31
# nissan         17
# mazda          15
# honda          13
# mitsubishi     13
# subaru         12
# peugeot        11
# volvo          11
# volkswagen      9
# dodge           9
# buick           8
# bmw             8
# audi            7
# plymouth        7
# saab            6
# isuzu           4
# porsche         4
# alfa-romero     3
# chevrolet       3
# jaguar          3
# vw              2
# maxda           2
# renault         2
# toyouta         1
# vokswagen       1
# Nissan          1
# mercury         1
# porcshce        1
# Name: CompanyName, dtype: int64

# %%
df['CompanyName'] = df['CompanyName'].str.lower()
df['CompanyName'].nunique()
# Out:
# 27

# %%
df['CompanyName'].replace({'maxda':'mazda','porcshce':'porsche','toyouta':'toyota','vokswagen':'volkswagen','vw':'volkswagen'},inplace=True)

# %%
df.sample(3)
# Out:
#      symboling CompanyName fueltype aspiration doornumber    carbody  \
# 122          1    plymouth      gas        std       four      sedan
# 66           0       mazda   diesel        std       four      sedan
# 29           3       dodge      gas      turbo        two  hatchback
#
#     drivewheel enginelocation  wheelbase  carlength  ...  enginesize  \
# 122        fwd          front       93.7      167.3  ...          98
# 66         rwd          front      104.9      175.0  ...         134
# 29         fwd          front       95.9      173.2  ...         156
#
#      fuelsystem  boreratio stroke compressionratio  horsepower peakrpm  \
# 122        2bbl       2.97   3.23              9.4          68    5500
# 66          idi       3.43   3.64             22.0          72    4200
# 29          mfi       3.60   3.90              7.0         145    5000
#
#      citympg  highwaympg    price
# 122       31          38   7609.0
# 66        31          39  18344.0
# ...

# %%
df['fueltype'].value_counts()
# Out:
# gas       185
# diesel     20
# Name: fueltype, dtype: int64

# %%
fuel_gas = pd.get_dummies(df['fueltype'])
fuel_gas.drop('diesel',axis=1,inplace=True)
fuel_gas
# Out:
#      gas
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
# ..   ...
# 200    1
# 201    1
# 202    1
# 203    0
# 204    1
#
# [205 rows x 1 columns]

# %%
df['aspiration'].value_counts()
# Out:
# std      168
# turbo     37
# Name: aspiration, dtype: int64

# %%
aspiration_turbo = pd.get_dummies(df['aspiration'])
aspiration_turbo.drop('std',inplace=True,axis=1)
aspiration_turbo
# Out:
#      turbo
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ..     ...
# 200      0
# 201      1
# 202      0
# 203      1
# 204      1
#
# [205 rows x 1 columns]

# %%
df['fuel_gas'] = fuel_gas
df['aspiration_turbo'] = aspiration_turbo

# %%
#fuel_gas --> 1
#fuel_diesel --> 0

#aspiration std -->0
#aspiration turbo -->1

# %%
df.drop(['fueltype','aspiration'],axis=1,inplace=True)

# %%
df.sample(3)
# Out:
#      symboling CompanyName doornumber carbody drivewheel enginelocation  \
# 14           1         bmw       four   sedan        rwd          front
# 111          0     peugeot       four   sedan        rwd          front
# 198         -2       volvo       four   sedan        rwd          front
#
#      wheelbase  carlength  carwidth  carheight  ...  boreratio stroke  \
# 14       103.5      189.0      66.9       55.7  ...       3.31   3.19
# 111      107.9      186.7      68.4       56.7  ...       3.46   2.19
# 198      104.3      188.8      67.2       56.2  ...       3.62   3.15
#
#     compressionratio  horsepower peakrpm  citympg  highwaympg    price  \
# 14               9.0         121    4250       20          25  24565.0
# 111              8.4          95    5000       19          24  15580.0
# 198              7.5         162    5100       17          22  18420.0
#
#      fuel_gas  aspiration_turbo
# 14          1                 0
# 111         1                 0
# ...

# %%
df['symboling'].value_counts()
# Out:
#  0    67
#  1    54
#  2    32
#  3    27
# -1    22
# -2     3
# Name: symboling, dtype: int64

# %%
df['symboling'].replace({0:'Safe',1:'Neutral',2:'Risky',3:'Dangerous',-1:'Moderately_Safe',-2:'Very_Safe'},inplace=True)

# %%
df.sample(3)
# Out:
#    symboling CompanyName doornumber    carbody drivewheel enginelocation  \
# 37      Safe       honda        two  hatchback        fwd          front
# 9       Safe        audi        two  hatchback        4wd          front
# 3      Risky        audi       four      sedan        fwd          front
#
#     wheelbase  carlength  carwidth  carheight  ...  boreratio stroke  \
# 37       96.5      167.5      65.2       53.3  ...       3.15   3.58
# 9        99.5      178.2      67.9       52.0  ...       3.13   3.40
# 3        99.8      176.6      66.2       54.3  ...       3.19   3.40
#
#    compressionratio  horsepower peakrpm  citympg  highwaympg      price  \
# 37              9.0          86    5800       27          33   7895.000
# 9               7.0         160    5500       16          22  17859.167
# 3              10.0         102    5500       24          30  13950.000
#
#     fuel_gas  aspiration_turbo
# 37         1                 0
# 9          1                 1
# ...

# %%
#Door Number

two_door = pd.get_dummies(df['doornumber'])
two_door
two_door.drop('four',axis=1,inplace=True)

# %%
df['two_door'] = two_door
df.sample(3)
# Out:
#            symboling CompanyName doornumber    carbody drivewheel  \
# 158             Safe      toyota       four      sedan        fwd
# 123  Moderately_Safe    plymouth       four      wagon        fwd
# 80         Dangerous  mitsubishi        two  hatchback        fwd
#
#     enginelocation  wheelbase  carlength  carwidth  carheight  ...  stroke  \
# 158          front       95.7      166.3      64.4       53.0  ...    3.35
# 123          front      103.3      174.6      64.6       59.8  ...    3.46
# 80           front       96.3      173.0      65.4       49.4  ...    3.46
#
#     compressionratio horsepower  peakrpm citympg  highwaympg   price  \
# 158             22.5         56     4500      34          36  7898.0
# 123              8.5         88     5000      24          30  8921.0
# 80               7.5        116     5500      23          30  9959.0
#
#      fuel_gas  aspiration_turbo  two_door
# 158         0                 0         0
# ...

# %%
df.drop('doornumber',axis=1,inplace=True)

# %%
df.sample(3)
# Out:
#            symboling CompanyName carbody drivewheel enginelocation  wheelbase  \
# 36              Safe       honda   wagon        fwd          front       96.5
# 107             Safe     peugeot   sedan        rwd          front      107.9
# 204  Moderately_Safe       volvo   sedan        rwd          front      109.1
#
#      carlength  carwidth  carheight  curbweight  ... stroke compressionratio  \
# 36       157.1      63.9       58.3        2024  ...   3.41              9.2
# 107      186.7      68.4       56.7        3020  ...   3.19              8.4
# 204      188.8      68.9       55.5        3062  ...   3.15              9.5
#
#      horsepower peakrpm  citympg  highwaympg    price  fuel_gas  \
# 36           76    6000       30          34   7295.0         1
# 107          97    5000       19          24  11900.0         1
# 204         114    5400       19          25  22625.0         1
#
#      aspiration_turbo  two_door
# 36                  0         0
# ...

# %% [markdown]
# # Data Visualization

# %%
#x = df.groupby('CompanyName').value_counts()

# %%
plt.figure(figsize=(10,8))
df['CompanyName'].value_counts().plot(kind='bar',rot=45)

label = 0.3
for i, count in enumerate(df['CompanyName'].value_counts()):
        plt.text(x=i,y=count+label,s=count,ha='center')
plt.show()

# %%
data = df.groupby('CompanyName')['price'].mean().sort_values()
data
# Out:
# CompanyName
# chevrolet       6007.000000
# dodge           7875.444444
# plymouth        7963.428571
# honda           8184.692308
# subaru          8541.250000
# isuzu           8916.500000
# mitsubishi      9239.769231
# renault         9595.000000
# toyota          9885.812500
# volkswagen     10077.500000
# nissan         10415.666667
# mazda          10652.882353
# saab           15223.333333
# peugeot        15489.090909
# alfa-romero    15498.333333
# mercury        16503.000000
# audi           17859.166714
# volvo          18063.181818
# bmw            26118.750000
# porsche        31400.500000
# buick          33647.000000
# jaguar         34600.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(20,16))

data = pd.DataFrame(df.groupby('CompanyName')['price'].mean().sort_values(ascending=False))
#df = pd.DataFrame(df)

data = data.sort_values(by='price')
data

data.reset_index()
# Out:
#     CompanyName         price
# 0     chevrolet   6007.000000
# 1         dodge   7875.444444
# 2      plymouth   7963.428571
# 3         honda   8184.692308
# 4        subaru   8541.250000
# 5         isuzu   8916.500000
# 6    mitsubishi   9239.769231
# 7       renault   9595.000000
# 8        toyota   9885.812500
# 9    volkswagen  10077.500000
# 10       nissan  10415.666667
# 11        mazda  10652.882353
# 12         saab  15223.333333
# 13      peugeot  15489.090909
# 14  alfa-romero  15498.333333
# 15      mercury  16503.000000
# 16         audi  17859.166714
# 17        volvo  18063.181818
# 18          bmw  26118.750000
# 19      porsche  31400.500000
# 20        buick  33647.000000
# 21       jaguar  34600.000000

# %% [markdown]
# Chevrolet has the cheapest average price amongst all companies.
#
# Jaguar has the highest average price.

# %%
data.sort_values(by='price',ascending=False)
# Out:
#                     price
# CompanyName
# jaguar       34600.000000
# buick        33647.000000
# porsche      31400.500000
# bmw          26118.750000
# volvo        18063.181818
# audi         17859.166714
# mercury      16503.000000
# alfa-romero  15498.333333
# peugeot      15489.090909
# saab         15223.333333
# mazda        10652.882353
# nissan       10415.666667
# volkswagen   10077.500000
# toyota        9885.812500
# renault       9595.000000
# mitsubishi    9239.769231
# isuzu         8916.500000
# subaru        8541.250000
# honda         8184.692308
# plymouth      7963.428571
# dodge         7875.444444
# chevrolet     6007.000000

# %%
data = data['price'].apply(lambda x: 'Low' if x < 10000 and x <= 17000 else 'Medium' if x > 17000 else 'Top' )

# %%
data.head()
# Out:
# CompanyName
# chevrolet    Low
# dodge        Low
# plymouth     Low
# honda        Low
# subaru       Low
# Name: price, dtype: object

# %%
df.sample(3)
# Out:
#            symboling CompanyName carbody drivewheel enginelocation  wheelbase  \
# 91           Neutral      nissan   sedan        fwd          front       94.5
# 25           Neutral       dodge   sedan        fwd          front       93.7
# 197  Moderately_Safe       volvo   wagon        rwd          front      104.3
#
#      carlength  carwidth  carheight  curbweight  ... stroke compressionratio  \
# 91       165.3      63.8       54.5        1918  ...   3.29              9.4
# 25       157.3      63.8       50.6        1989  ...   3.23              9.4
# 197      188.8      67.2       57.5        3042  ...   3.15              9.5
#
#      horsepower peakrpm  citympg  highwaympg    price  fuel_gas  \
# 91           69    5200       31          37   6649.0         1
# 25           68    5500       31          38   6692.0         1
# 197         114    5400       24          28  16515.0         1
#
#      aspiration_turbo  two_door
# 91                  0         1
# ...

# %%
data.head()
# Out:
# CompanyName
# chevrolet    Low
# dodge        Low
# plymouth     Low
# honda        Low
# subaru       Low
# Name: price, dtype: object

# %%
df.sample(3)
# Out:
#            symboling CompanyName carbody drivewheel enginelocation  wheelbase  \
# 67   Moderately_Safe       buick   sedan        rwd          front      110.0
# 141             Safe      subaru   sedan        fwd          front       97.2
# 108             Safe     peugeot   sedan        rwd          front      107.9
#
#      carlength  carwidth  carheight  curbweight  ... stroke compressionratio  \
# 67       190.9      70.3       56.5        3515  ...   3.64             21.5
# 141      172.0      65.4       52.5        2145  ...   2.64              9.5
# 108      186.7      68.4       56.7        3197  ...   3.52             21.0
#
#      horsepower peakrpm  citympg  highwaympg    price  fuel_gas  \
# 67          123    4350       22          25  25552.0         0
# 141          82    4800       32          37   7126.0         1
# 108          95    4150       28          33  13200.0         0
#
#      aspiration_turbo  two_door
# 67                  1         0
# ...

# %%
data.sample(3)
# Out:
# CompanyName
# mazda          Top
# mercury        Top
# alfa-romero    Top
# Name: price, dtype: object

# %%
data.reset_index(drop=True)
data.sample(3)
# Out:
# CompanyName
# renault           Low
# volvo          Medium
# alfa-romero       Top
# Name: price, dtype: object

# %%
data = pd.DataFrame(data)

# %%
data.reset_index(drop=True)

data['price'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 22 entries, chevrolet to jaguar
# Series name: price
# Non-Null Count  Dtype
# --------------  -----
# 22 non-null     object
# dtypes: object(1)
# memory usage: 352.0+ bytes

# %%
data = pd.DataFrame(data)

# %%
import pandas as pd

# Sample data
data = {
    'CompanyName': ['chevrolet', 'dodge', 'plymouth', 'honda', 'subaru', 'isuzu', 'mitsubishi', 'renault', 'toyota', 'volkswagen', 'nissan', 'mazda', 'saab', 'peugeot', 'alfa-romero', 'mercury', 'audi', 'volvo', 'bmw', 'porsche', 'buick', 'jaguar'],
    'Label': ['Low', 'Low', 'Low', 'Low', 'Low', 'Low', 'Low', 'Low', 'Low', 'Top', 'Top', 'Top', 'Top', 'Top', 'Top', 'Top', 'Medium', 'Medium', 'Medium', 'Medium', 'Medium', 'Medium']
}

data = pd.DataFrame(data)

print(data)
# Out:
#     CompanyName   Label
# 0     chevrolet     Low
# 1         dodge     Low
# 2      plymouth     Low
# 3         honda     Low
# 4        subaru     Low
# 5         isuzu     Low
# 6    mitsubishi     Low
# 7       renault     Low
# 8        toyota     Low
# 9    volkswagen     Top
# 10       nissan     Top
# 11        mazda     Top
# 12         saab     Top
# 13      peugeot     Top
# 14  alfa-romero     Top
# 15      mercury     Top
# 16         audi  Medium
# 17        volvo  Medium
# 18          bmw  Medium
# 19      porsche  Medium
# 20        buick  Medium
# 21       jaguar  Medium

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CompanyName  22 non-null     object
#  1   Label        22 non-null     object
# dtypes: object(2)
# memory usage: 480.0+ bytes

# %%
data
# Out:
#     CompanyName   Label
# 0     chevrolet     Low
# 1         dodge     Low
# 2      plymouth     Low
# 3         honda     Low
# 4        subaru     Low
# 5         isuzu     Low
# 6    mitsubishi     Low
# 7       renault     Low
# 8        toyota     Low
# 9    volkswagen     Top
# 10       nissan     Top
# 11        mazda     Top
# 12         saab     Top
# 13      peugeot     Top
# 14  alfa-romero     Top
# 15      mercury     Top
# 16         audi  Medium
# 17        volvo  Medium
# 18          bmw  Medium
# 19      porsche  Medium
# 20        buick  Medium
# 21       jaguar  Medium

# %%
data.replace({'Label':'Variant'},inplace=True)

# %%
data.shape
# Out:
# (22, 2)

# %%
df.shape
# Out:
# (205, 25)

# %%
df.columns
# Out:
# Index(['symboling', 'CompanyName', 'carbody', 'drivewheel', 'enginelocation',
#        'wheelbase', 'carlength', 'carwidth', 'carheight', 'curbweight',
#        'enginetype', 'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio',
#        'stroke', 'compressionratio', 'horsepower', 'peakrpm', 'citympg',
#        'highwaympg', 'price', 'fuel_gas', 'aspiration_turbo', 'two_door'],
#       dtype='object')

# %%
df.sample(3)
# Out:
#     symboling CompanyName    carbody drivewheel enginelocation  wheelbase  \
# 143      Safe      subaru      sedan        fwd          front       97.2
# 109      Safe     peugeot      wagon        rwd          front      114.2
# 34    Neutral       honda  hatchback        fwd          front       93.7
#
#      carlength  carwidth  carheight  curbweight  ... stroke compressionratio  \
# 143      172.0      65.4       52.5        2340  ...   2.64              9.0
# 109      198.9      68.4       58.7        3230  ...   3.19              8.4
# 34       150.0      64.0       52.6        1956  ...   3.41              9.2
#
#      horsepower peakrpm  citympg  highwaympg    price  fuel_gas  \
# 143          94    5200       26          32   9960.0         1
# 109          97    5000       19          24  12440.0         1
# 34           76    6000       30          34   7129.0         1
#
#      aspiration_turbo  two_door
# 143                 0         0
# ...

# %%
data.value_counts()
# Out:
# CompanyName  Label
# alfa-romero  Top       1
# audi         Medium    1
# volkswagen   Top       1
# toyota       Low       1
# subaru       Low       1
# saab         Top       1
# renault      Low       1
# porsche      Medium    1
# plymouth     Low       1
# peugeot      Top       1
# nissan       Top       1
# mitsubishi   Low       1
# mercury      Top       1
# mazda        Top       1
# jaguar       Medium    1
# isuzu        Low       1
# honda        Low       1
# dodge        Low       1
# chevrolet    Low       1
# buick        Medium    1
# bmw          Medium    1
# volvo        Medium    1
# dtype: int64

# %%
df['carbody'].value_counts()
# Out:
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: carbody, dtype: int64

# %%
df['drivewheel'].value_counts()
# Out:
# fwd    120
# rwd     76
# 4wd      9
# Name: drivewheel, dtype: int64

# %%
plt.figure(figsize=(20,6))

plt.subplot(1,2,1)
plt.title('Car Price Distribution Plot')
sns.distplot(df.price)

plt.subplot(1,2,2)
plt.title('Car Price Spread')
sns.boxplot(y=df.price)

plt.show()
# Out:
# C:\Users\UDHAYA KUMAR . R\AppData\Local\Temp\ipykernel_60112\629516243.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.price)

# %% [markdown]
# The plot is right-skewed, meaning that the most prices in the dataset are low (Below 15,000).

# %%
def pairplot(x,y):
    sns.pairplot(df,x_vars=[x,y],y_vars='price',height=4,kind='scatter')
    plt.show()
    

pairplot('highwaympg','citympg')
pairplot('carlength', 'carwidth')
pairplot('carwidth', 'curbweight')

# %%
df.columns
# Out:
# Index(['symboling', 'CompanyName', 'carbody', 'drivewheel', 'enginelocation',
#        'wheelbase', 'carlength', 'carwidth', 'carheight', 'curbweight',
#        'enginetype', 'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio',
#        'stroke', 'compressionratio', 'horsepower', 'peakrpm', 'citympg',
#        'highwaympg', 'price', 'fuel_gas', 'aspiration_turbo', 'two_door'],
#       dtype='object')

# %%
def pp(x,y,z):
    sns.pairplot(df,x_vars=[x,y,z],y_vars='price',kind='scatter')
    plt.show()
    
pp('stroke', 'compressionratio', 'horsepower')
pp('cylindernumber', 'enginesize', 'fuelsystem')
pp('carlength', 'carwidth', 'carheight')
pp('enginelocation','enginetype','enginesize')
pp('citympg','highwaympg','stroke')

# %%
df['cylindernumber'].value_counts()
# Out:
# four      159
# six        24
# five       11
# eight       5
# two         4
# three       1
# twelve      1
# Name: cylindernumber, dtype: int64

# %%
df['cylindernumber'].replace({'two':2,'three':3,'four':4,'five':5,'six':6,'eight':8,'twelve':12},inplace=True)

# %%
df['cylindernumber'].value_counts()
# Out:
# 4     159
# 6      24
# 5      11
# 8       5
# 2       4
# 3       1
# 12      1
# Name: cylindernumber, dtype: int64

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(),annot=True)

plt.show()
# Out:
# C:\Users\UDHAYA KUMAR . R\AppData\Local\Temp\ipykernel_60112\4029676063.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)

# %%
df.drop(['compressionratio','carwidth','carheight','carlength','wheelbase','curbweight'],axis=1,inplace=True)

# %%
df.sample(3)
# Out:
#     symboling CompanyName    carbody drivewheel enginelocation enginetype  \
# 34    Neutral       honda  hatchback        fwd          front        ohc
# 10      Risky         bmw      sedan        rwd          front        ohc
# 139     Risky      subaru  hatchback        fwd          front       ohcf
#
#      cylindernumber  enginesize fuelsystem  boreratio  stroke  horsepower  \
# 34                4          92       1bbl       2.91    3.41          76
# 10                4         108       mpfi       3.50    2.80         101
# 139               4         108       2bbl       3.62    2.64          73
#
#      peakrpm  citympg  highwaympg    price  fuel_gas  aspiration_turbo  \
# 34      6000       30          34   7129.0         1                 0
# 10      5800       23          29  16430.0         1                 0
# 139     4400       26          31   7053.0         1                 0
#
#      two_door
# 34          1
# 10          1
# 139         1

# %%
df.drop(['drivewheel','enginelocation','enginetype'],axis=1,inplace=True)

# %%
df.sample(3)
# Out:
#            symboling CompanyName carbody  cylindernumber  enginesize  \
# 40              Safe       honda   sedan               4         110
# 197  Moderately_Safe       volvo   wagon               4         141
# 85           Neutral  mitsubishi   sedan               4         122
#
#     fuelsystem  boreratio  stroke  horsepower  peakrpm  citympg  highwaympg  \
# 40        1bbl       3.15    3.58          86     5800       27          33
# 197       mpfi       3.78    3.15         114     5400       24          28
# 85        2bbl       3.35    3.46          88     5000       25          32
#
#        price  fuel_gas  aspiration_turbo  two_door
# 40   10295.0         1                 0         0
# 197  16515.0         1                 0         0
# 85    6989.0         1                 0         0

# %%
df = pd.get_dummies(df)

# %%
X = df.drop(['price'],axis=1)
y = df['price']

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.30,random_state=0)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
lr.coef_
# Out:
# array([-3.18119853e+03,  1.84444476e+02, -1.13069887e+04, -2.80723227e+03,
#         2.72687171e+01,  1.22981738e+00, -2.48061540e+02,  1.05525431e+02,
#        -5.46271819e+02,  1.71049216e+03, -7.91779087e+02,  8.03531911e+02,
#         8.89406947e+02,  8.51628604e+01, -3.25871874e+02,  1.83440909e+02,
#        -1.63567075e+03, -5.41573965e+03,  9.60254369e+02,  7.76157648e+03,
#         7.50496639e+03, -2.79932738e+03, -4.65708278e+03, -1.38517751e+03,
#        -4.73456614e+03,  5.15439644e+03, -1.77277459e+03,  6.36646291e-12,
#        -4.50228043e+03, -2.89499778e+03,  7.47955717e+02, -4.41086687e+03,
#         1.07583255e+04,  2.84217094e-13,  6.54924451e+02,  6.91567260e+01,
#        -2.21517879e+03, -1.95216261e+03,  3.12859844e+03,  4.27387519e+03,
#        -8.05628125e+02, -8.74710939e+02, -8.86838819e+02, -1.70669731e+03,
#        -2.68399412e+03, -8.13990438e+01,  1.36627710e+03,  5.46271819e+02,
# ...

# %%
lr.intercept_
# Out:
# 46458.741102697815

# %%
from sklearn.metrics import r2_score

r2_score(y_test,y_pred)
# Out:
# 0.8552099128687966

# %%
lr.score(X,y)
# Out:
# 0.9308439374389308
